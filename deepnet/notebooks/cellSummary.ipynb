# %%
import tensorflow as tf

efile = '/home/mayank/work/poseEstimation/cache/romainLegBottom/eval_test_summary/events.out.tfevents.1484832405.mayankWS'

# %%
vals = []
names = []
first = True
for aa in tf.train.summary_iterator(efile):
    if not len(aa.summary.value):
        continue
    if first:
        for ndx,bb in enumerate(aa.summary.value):
            vals.append([])
            names.append(bb.tag)
        first = False
    for ndx,bb in enumerate(aa.summary.value):
        vals[ndx].append(bb.simple_value)

# %%
for n in names:
    print n
# Out:
# eval/scale0/layer1_X/weights_1/summaries/stddev_1
# eval/scale0/layer1_X/conv/summaries/stddev_1
# eval/scale0/layer2/weights_1/summaries/stddev_1
# eval/scale0/layer2/conv/summaries/stddev_1
# eval/scale0/layer3/weights_1/summaries/stddev_1
# eval/scale0/layer3/conv/summaries/stddev_1
# eval/scale0/layer4/weights_1/summaries/stddev_1
# eval/scale0/layer4/conv/summaries/stddev_1
# eval/scale0/layer5/weights_1/summaries/stddev_1
# eval/scale0/layer5/conv/summaries/stddev_1
# eval/scale1/layer1_X/conv/summaries/stddev_1
# eval/scale1/layer2/conv/summaries/stddev_1
# eval/scale1/layer3/conv/summaries/stddev_1
# eval/scale1/layer4/conv/summaries/stddev_1
# eval/scale1/layer5/conv/summaries/stddev_1
# eval/scale2/layer1_X/conv/summaries/stddev_1
# eval/scale2/layer2/conv/summaries/stddev_1
# eval/scale2/layer3/conv/summaries/stddev_1
# eval/scale2/layer4/conv/summaries/stddev_1
# eval/scale2/layer5/conv/summaries/stddev_1
# eval/scale0_scores/layer1_X/weights_1/summaries/stddev_1
# eval/scale0_scores/layer1_X/conv/summaries/stddev_1
# eval/scale0_scores/layer2/weights_1/summaries/stddev_1
# eval/scale0_scores/layer2/conv/summaries/stddev_1
# eval/scale0_scores/layer3/weights_1/summaries/stddev_1
# eval/scale0_scores/layer3/conv/summaries/stddev_1
# eval/scale0_scores/layer4/weights_1/summaries/stddev_1
# eval/scale0_scores/layer4/conv/summaries/stddev_1
# eval/scale0_scores/layer5/weights_1/summaries/stddev_1
# eval/scale0_scores/layer5/conv/summaries/stddev_1
# eval/scale1_scores/layer1_X/conv/summaries/stddev_1
# eval/scale1_scores/layer2/conv/summaries/stddev_1
# eval/scale1_scores/layer3/conv/summaries/stddev_1
# eval/scale1_scores/layer4/conv/summaries/stddev_1
# eval/scale1_scores/layer5/conv/summaries/stddev_1
# eval/scale2_scores/layer1_X/conv/summaries/stddev_1
# eval/scale2_scores/layer2/conv/summaries/stddev_1
# eval/scale2_scores/layer3/conv/summaries/stddev_1
# eval/scale2_scores/layer4/conv/summaries/stddev_1
# eval/scale2_scores/layer5/conv/summaries/stddev_1
# eval/layer6/weights_1/summaries/stddev_1
# eval/layer6/biases_1/summaries/stddev_1
# eval/layer6/conv/summaries/stddev_1
# eval/layer7/weights_1/summaries/stddev_1
# eval/layer7/biases_1/summaries/stddev_1
# eval/layer7/conv/summaries/stddev_1
# eval/layer8/weights_1/summaries/stddev_1
# eval/layer8/biases_1/summaries/stddev_1
# eval/layer8/out/summaries/stddev_1
# input_producer/queue/input_producer/fraction_of_32_full
# input_producer_1/queue/input_producer_1/fraction_of_32_full
# cross_entropy

# %%
for ndx in range(50,len(names)):
    plt.figure()
    plt.plot(vals[ndx])
    plt.title(names[ndx])

# %%
ndx = 51
plt.figure()
plt.plot(vals[ndx][2:])
plt.title(names[ndx])
